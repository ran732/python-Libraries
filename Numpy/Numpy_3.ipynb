# %%
import numpy as np

# %%
np.random.random()  #random (0-1)
# Out:
# 0.013403894311980746

# %%
np.random.seed(1)   # random same value again and again
np.random.random()
# Out:
# 0.417022004702574

# %%
np.random.uniform(1,100)   #range
# Out:
# 35.210511977261724

# %%
np.random.uniform(1,100,10).reshape(2,5)
# Out:
# array([[ 2.81053946, 75.26428718, 98.8972478 , 75.06839978, 28.76395521],
#        [79.13865352, 11.21937465, 45.34145909, 90.95095481, 30.06780069]])

# %%
np.random.randint(1,100,15).reshape(3,5)   #integer in given range
# Out:
# array([[18, 43, 21, 49, 23],
#        [14, 98, 54, 85, 11],
#        [97, 56, 62, 57, 90]], dtype=int32)

# %%
a=np.random.randint(1,10,6)
a
# Out:
# array([5, 7, 9, 9, 3, 8], dtype=int32)

# %%
np.max(a)
# Out:
# np.int32(9)

# %%
np.min(a)
# Out:
# np.int32(3)

# %%
np.argmax(a)  #index of max value
# Out:
# np.int64(2)

# %%
np.argmin(a)  #index of min value
# Out:
# np.int64(4)

# %%
a=np.random.randint(1,110,6)
a
# Out:
# array([41, 79, 46, 88, 17, 29], dtype=int32)

# %%
a[a%2==0] = -1
a
# Out:
# array([41, 79, -1, -1, 17, 29], dtype=int32)

# %%
a=np.random.randint(1,15,6)
a
# Out:
# array([14,  2,  3,  5,  4,  1], dtype=int32)

# %%
np.where(a%2==1,-1,a) # if condition true return a otherwise it return false
# Out:
# array([14,  2, -1, -1,  4, -1], dtype=int32)

# %%
a=np.random.randint(1,50,10)
a
# Out:
# array([33,  9, 21, 14, 16, 42,  1, 45, 20, 25], dtype=int32)

# %%
np.sort(a)
# Out:
# array([ 1,  9, 14, 16, 20, 21, 25, 33, 42, 45], dtype=int32)

# %%
np.percentile(a,25)
# Out:
# np.float64(14.5)

# %%
np.percentile(a,50)
# Out:
# np.float64(20.5)

# %%
np.percentile(a,100)
# Out:
# np.float64(45.0)
