# %%
import numpy as np

# %%
arr1=np.array([1,12,3,4,24,54])
arr2=np.array([5,2,74,8,4,5])

# %%
print(arr2-arr1)
# Out:
# [  4 -10  71   4 -20 -49]

# %%
print(arr2*arr1)
# Out:
# [  5  24 222  32  96 270]

# %%
print(arr2*2)
# Out:
# [ 10   4 148  16   8  10]

# %%
print(arr1>5)
# Out:
# [False  True False False  True  True]

# %%
arr3=np.arange(6).reshape(2,3)
arr4=np.arange(6,12).reshape(3,2)

# %%
print(arr3.dot(arr4))
# Out:
# [[ 28  31]
#  [100 112]]

# %%
print(arr1.dot(arr2))
# Out:
# 649

# %%
print((arr4))
# Out:
# [[ 6  7]
#  [ 8  9]
#  [10 11]]

# %%
print((arr4).max(axis=1))
# Out:
# [ 7  9 11]

# %%
print((arr4).min())
# Out:
# 6

# %%
print(arr4.sin())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 print(arr4.sin())
#
# AttributeError: 'numpy.ndarray' object has no attribute 'sin'

# %%
print(arr4.ndim)
# Out:
# 2

# %%
print(arr4.ravel())
# Out:
# [ 6  7  8  9 10 11]

# %%
print(arr4)
# Out:
# [[ 6  7]
#  [ 8  9]
#  [10 11]]

# %%
print(arr4.transpose())
# Out:
# [[ 6  8 10]
#  [ 7  9 11]]

# %%
print(arr3)
# Out:
# [[0 1 2]
#  [3 4 5]]

# %%
arr5=np.arange(12,18).reshape(2,3)
print(arr5)
# Out:
# [[12 13 14]
#  [15 16 17]]

# %%
print(np.hstack((arr3,arr5)))
# Out:
# [[ 0  1  2 12 13 14]
#  [ 3  4  5 15 16 17]]

# %%
print(np.vstack((arr3,arr5)))
# Out:
# [[ 0  1  2]
#  [ 3  4  5]
#  [12 13 14]
#  [15 16 17]]

# %%
print(np.vsplit(arr3,2))
# Out:
# [array([[0, 1, 2]]), array([[3, 4, 5]])]

# %%
import numpy  as np

# %%
arr=np.random.randint(low=1,high=100,size=20).reshape(4,5)
print(arr)
# Out:
# [[13  1 85 22 18]
#  [95 21 88 15 44]
#  [87 72 78 61 23]
#  [57 43 34 94 13]]

# %%
print(arr[0])
# Out:
# [48 38  2 16 87]

# %%
print(arr[2])
# Out:
# [49 37 46 28  4]

# %%
print(arr[1][2])  #14
# Out:
# 14

# %%
print(arr[3][3])
# Out:
# 7

# %%
print(arr[arr>50])
# Out:
# [87 98 64 69]

# %%
print(arr[(arr>50) & (arr%2==0)])
# Out:
# []
